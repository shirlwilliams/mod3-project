# %% [markdown]
# # EDA Comparisons
# Let's evaluate data comparisons

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('terry-clean.csv')
df.head()
# Out:
# /Users/shirlwilliams/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   subject_age_group  subject_id     go_/_sc_num  terry_stop_id  \
# 0           36 - 45          -1  20140000120677          92317
# 1           18 - 25          -1  20150000001670          32260
# 2            1 - 17          -1  20150000002451          46430
# 3            1 - 17          -1  20150000002815          51725
# 4           26 - 35          -1  20150000002815          51727
#
#   stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     7539           1963              M
# 2   Field Contact        None     7591           1985              M
# ...

# %%
df = df.replace('Gender Diverse (gender non-conforming and/or transgender)', 'Gender Diverse')

# %%
data = pd.read_csv('terry-cat-dummies.csv')
data.head()
# Out:
#    frisk_flag_-  frisk_flag_N  frisk_flag_Y  call_type_911  call_type_None  \
# 0             0             1             0              0               1
# 1             0             1             0              0               1
# 2             0             1             0              0               1
# 3             0             1             0              0               1
# 4             0             1             0              0               1
#
#    call_type_ONVIEW  call_type_Other  subject_age_group_1 - 17  \
# 0                 0                0                         0
# 1                 0                0                         0
# 2                 0                0                         1
# 3                 0                0                         1
# 4                 0                0                         0
#
#    subject_age_group_18 - 25  subject_age_group_26 - 35  ...  \
# 0                          0                          0  ...
# ...

# %%
#df['arrest'] = df.arrest_flag.replace('N', 0).replace('Y', 1)

# %%
ax = sns.countplot(y='call_type', data=df, hue='arrest_flag',edgecolor=sns.color_palette("dark", 3), 
                   palette='pastel', order = df['call_type'].value_counts().index);
total = len(df['call_type'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
title = 'call_type'.replace('_', ' ').title()
plt.title(title)
plt.ylabel(title)
plt.xlabel('Count')
plt.show()

# %%
plt.figure(figsize=(13, 10))
ax = sns.countplot(y='subject_perceived_race', data=df, hue='arrest_flag',edgecolor=sns.color_palette("dark", 3), 
                   palette='pastel', order = df['subject_perceived_race'].value_counts().index);
total = len(df['subject_perceived_race'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
ax.legend(loc='lower right')
title = 'perceived_race'.replace('_', ' ').title()
plt.title(title)
plt.ylabel(title)
plt.xlabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
ax = sns.countplot(y='frisk_flag', data=df, hue='arrest_flag',edgecolor=sns.color_palette("dark", 3), 
                   palette='pastel', order = df['frisk_flag'].value_counts().index);
total = len(df['frisk_flag'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
ax.legend(loc='lower right')
title = 'frisk_flag'.replace('_', ' ').title()
plt.title(title)
plt.ylabel(title)
plt.xlabel('Count')
plt.show()

# %%
arrested = df[df['arrest_flag'] == 'Y']
arrested
# Out:
#       subject_age_group   subject_id     go_/_sc_num  terry_stop_id  \
# 1157             1 - 17   8273276997  20190000204158     8273686053
# 1169            26 - 35   8355337122  20190000229094     8355333909
# 1173            26 - 35   8926195570  20190000279716     8927975747
# 1186            36 - 45   8613729887  20190000257632     8613721148
# 1188            36 - 45   9007238661  20190000281067     9007034032
# ...                 ...          ...             ...            ...
# 40289      56 and Above  12248459262  20200000031420    12248474534
# 40291      56 and Above  12634426429  20200000068784    12634415415
# 40299      56 and Above   9587645130  20190000288157     9587776187
# 40302      56 and Above  10076866529  20190000329876    10104103280
# 40308      56 and Above  11982557407  20190000446941    11986233973
#
#       stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 1157           Arrest        None     7428           1963              M
# ...

# %%
for col in df.drop(columns=['go_/_sc_num', 'terry_stop_id', 'officer_id', 'subject_id', 'reported_date',
                            'officer_squad', 'officer_yob', 'precinct', 'sector', 'beat', 'final_call_type', 
                            'initial_call_type', 'reported_time', 'arrest_flag']).columns:
    ax = sns.countplot(y=col, data=df, edgecolor=sns.color_palette("dark", 3), palette='pastel',
                  order = df[col].value_counts().index);
    total = len(df[col])
    for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y))
    title = col.replace('_', ' ').title()
    plt.title(title)
    plt.ylabel(title, fontsize=12)
    plt.xlabel('Count',fontsize=12)
    plt.show()

# %%
for col in arrested.drop(columns=['go_/_sc_num', 'terry_stop_id', 'officer_id', 'subject_id', 'reported_date',
                                  'officer_squad', 'officer_yob', 'precinct', 'sector', 'beat', 'final_call_type', 
                                  'initial_call_type', 'reported_time']).columns:
    ax = sns.countplot(y=col, data=arrested, edgecolor=sns.color_palette("dark", 3), palette='pastel',
                       order = df[col].value_counts().index);
    sns.despine(left=False)
    
    total = len(arrested[col])
    for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y), fontsize=14)
    title = col.replace('_', ' ').title()
    plt.title(title + ' Arrested', fontsize=18)
    plt.ylabel(title, fontsize=16)
    plt.xlabel('Count', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()

# %%
#Set general plot properties
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

#Plot 1 - background - "total" (top) series
sns.countplot(y = df['officer_race'], palette='pastel', edgecolor = 'crimson', 
              order = df['subject_perceived_race'].value_counts().index)

#Plot 2 - overlay - "bottom" series
bottom_plot = sns.countplot(y = arrested['subject_perceived_race'], palette='deep', edgecolor = 'blue',
                           order = df['subject_perceived_race'].value_counts().index)
topbar = plt.Rectangle((0,0),1,1,fc="lightpink", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='steelblue',  edgecolor = 'none',)
l = plt.legend([bottombar, topbar], ['subject_perceived_race','Officer Race'], loc=4, ncol = 2, prop={'size':20})
l.draw_frame(False)

#Optional code - Make plot look nicer
sns.despine(left=True)
bottom_plot.set_ylabel("Perceived Gender of Subject")
bottom_plot.set_xlabel("Count")
bottom_plot.set_title("Perceived Race of Subject").set_fontsize(24)

#Set fonts to consistent 18 pt size
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(20)

# %%
for col in arrested.drop(columns=['go_/_sc_num', 'terry_stop_id', 'officer_id', 'subject_id', 'reported_date',
                                  'officer_squad', 'officer_yob', 'precinct', 'sector', 'beat', 'final_call_type', 
                                  'initial_call_type', 'reported_time']).columns:
    #Set general plot properties
    sns.set_style("white")
    #sns.set_context({"figure.figsize": (24, 10)})

    #Plot 1 - background - "total" (top) series
    sns.countplot(y = df[col], palette='pastel', edgecolor = 'crimson', order = df[col].value_counts().index)

    #Plot 2 - overlay - "bottom" series
    bottom_plot = sns.countplot(y = arrested[col], palette='deep', edgecolor = 'blue',
                               order = df[col].value_counts().index)
    topbar = plt.Rectangle((0,0),1,1,fc="lightpink", edgecolor = 'none')
    bottombar = plt.Rectangle((0,0),1,1,fc='steelblue',  edgecolor = 'none',)
    l = plt.legend([bottombar, topbar], ['Arrested', 'Total'], loc=4, ncol = 2, prop={'size':24})
    l.draw_frame(False)
    title = col.replace('_', ' ').title()

    #Optional code - Make plot look nicer
    sns.despine(left=True)
    bottom_plot.set_ylabel(title)
    bottom_plot.set_xlabel("Count")
    bottom_plot.set_title(title).set_fontsize(24)

    #Set fonts to consistent 24 pt size
    for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
                 bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
        item.set_fontsize(24)
    plt.show()

# %%
arrested.head()
# Out:
#      subject_age_group  subject_id     go_/_sc_num  terry_stop_id  \
# 1157            1 - 17  8273276997  20190000204158     8273686053
# 1169           26 - 35  8355337122  20190000229094     8355333909
# 1173           26 - 35  8926195570  20190000279716     8927975747
# 1186           36 - 45  8613729887  20190000257632     8613721148
# 1188           36 - 45  9007238661  20190000281067     9007034032
#
#      stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 1157          Arrest        None     7428           1963              M
# 1169          Arrest        None     8623           1991              M
# 1173          Arrest       Other     7797           1986              M
# 1186          Arrest        None     8608           1994              M
# 1188          Arrest        None     8587           1992              M
#
#             officer_race  ... reported_time  \
# 1157  Hispanic or Latino  ...      16:56:17
# ...

# %%
arrested.columns
# Out:
# Index(['subject_age_group', 'subject_id', 'go_/_sc_num', 'terry_stop_id',
#        'stop_resolution', 'weapon_type', 'officer_id', 'officer_yob',
#        'officer_gender', 'officer_race', 'subject_perceived_race',
#        'subject_perceived_gender', 'reported_date', 'reported_time',
#        'initial_call_type', 'final_call_type', 'call_type', 'officer_squad',
#        'arrest_flag', 'frisk_flag', 'precinct', 'sector', 'beat'],
#       dtype='object')

# %%
# !pip install plotly

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter(arrested, y="subject_perceived_race", color="officer_race")
fig.show()
# Out:
# <div>
#
#
#             <div id="a3368d7e-b6f9-45d8-98a3-825039381bf1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a3368d7e-b6f9-45d8-98a3-825039381bf1")) {
#                     Plotly.newPlot(
#                         'a3368d7e-b6f9-45d8-98a3-825039381bf1',
# ...

# %%
df.head()
# Out:
#   subject_age_group  subject_id     go_/_sc_num  terry_stop_id  \
# 0           36 - 45          -1  20140000120677          92317
# 1           18 - 25          -1  20150000001670          32260
# 2            1 - 17          -1  20150000002451          46430
# 3            1 - 17          -1  20150000002815          51725
# 4           26 - 35          -1  20150000002815          51727
#
#   stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     7539           1963              M
# 2   Field Contact        None     7591           1985              M
# 3   Field Contact        None     7456           1979              M
# 4   Field Contact        None     7456           1979              M
#
#                 officer_race  ... reported_time initial_call_type  \
# 0  Black or African American  ...      11:32:00                 -
# ...

# %%
# Mutli-Color Parallel Categories Diagram
# Create dimensions
race_dim = go.parcats.Dimension(values=arrested.subject_perceived_race, 
                                categoryorder='category ascending', label="Race")

weapon_dim = go.parcats.Dimension(values=arrested.weapon_type, label="Weapon")

gender_dim = go.parcats.Dimension(values=arrested.subject_perceived_gender, label="Gender")

# Create parcats trace
# color = arrested.frisk_flag;
# colorscale = [['Y', 'lightsteelblue'], ['N', 'mediumseagreen']];

fig = go.Figure(data = [go.Parcats(dimensions=[race_dim, gender_dim, weapon_dim],
        line={'color': color, 'colorscale': colorscale},
        hoveron='color', hoverinfo='count+probability',
        labelfont={'size': 18, 'family': 'Times'},
        tickfont={'size': 16, 'family': 'Times'},
        arrangement='freeform')])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-fe70d2161a12> in <module>
#      18         labelfont={'size': 18, 'family': 'Times'},
#      19         tickfont={'size': 16, 'family': 'Times'},
# ---> 20         arrangement='freeform')])
#      21
#      22 fig.show()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/plotly/graph_objs/__init__.py in __init__(self, arg, arrangement, bundlecolors, counts, countssrc, dimensions, dimensiondefaults, domain, hoverinfo, hoveron, hovertemplate, labelfont, line, meta, metasrc, name, sortpaths, stream, tickfont, uid, uirevision, visible, **kwargs)
#   46425         self["labelfont"] = labelfont if labelfont is not None else _v
#   46426         _v = arg.pop("line", None)
# > 46427         self["line"] = line if line is not None else _v
#   46428         _v = arg.pop("meta", None)
# ...

# %%
features = arrested.drop(columns=['go_/_sc_num', 'terry_stop_id', 'officer_id', 'subject_id', 'reported_date',
                                  'officer_squad', 'officer_yob', 'precinct', 'sector', 'beat', 'final_call_type', 
                                  'initial_call_type', 'reported_time', 'officer_gender', 'officer_race', 
                                  'arrest_flag', 'weapon_type', 'subject_perceived_gender', 'stop_resolution',
                                 'call_type'])
fig = px.parallel_categories(features)
fig.update_layout(
    title="Age, Race & Frisk",
        line={'color': color, 'colorscale': colorscale},
        hoveron='color', hoverinfo='count+probability',
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-af0eda0ee9c1> in <module>
#       8     title="Age, Race & Frisk",
#       9     line={'lightsteelblue': color, 'mediumseagreen': colorscale},
# ---> 10     hoveron='color', hoverinfo='count+probability',
#      11 )
#      12 fig.show()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/plotly/basedatatypes.py in update_layout(self, dict1, **kwargs)
#     914             The Figure object that the update_layout method was called on
#     915         """
# --> 916         self.layout.update(dict1, **kwargs)
#     917         return self
#     918
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/plotly/basedatatypes.py in update(self, dict1, **kwargs)
#    3554             with self.figure.batch_update():
#    3555                 BaseFigure._perform_update(self, dict1)
# ...
